# %% [markdown]
# # Setup

# %% [markdown]
# The following cell sets up everything necessary to train the GCN.

# %%
# Get contyent from drive
from google.colab import drive
drive.mount('/content/drive')

# Get GitHub token from Colab secrets
from google.colab import userdata
token = userdata.get('github_token')

# Clone the repo if it doesn't exist. If not then pull latest
import os
if not os.path.exists('/content/agnn'):
    # !git clone https://{token}@github.com/charlottedavidson524/alzheimers-gnn.git /content/agnn
# %cd /content/agnn
# !git pull

# Install project. Need to do this after a fresh clone
# !pip install -e . --quiet

# Copy data to local storage for faster access
if not os.path.exists("/content/graphs"):
    # !cp -r /content/drive/MyDrive/alzheimers-gnn-data/graphs /content/graphs
if not os.path.exists("/content/participants.tsv"):
    # !cp /content/drive/MyDrive/alzheimers-gnn-data/participants.tsv /content/participants.tsv

# Check that graphs, participants and results are all being stored where is expected
from agnn.paths import get_graphs_root, get_participants_tsv, get_results_root
print(f"Graphs: {get_graphs_root()}")
print(f"Participants: {get_participants_tsv()}")
print(f"Results: {get_results_root()}")

# GPU check
import torch
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'Not available'}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/agnn
# Already up to date.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for agnn (pyproject.toml) ... done
# Graphs: /content/graphs
# Participants: /content/participants.tsv
# Results: /content/drive/MyDrive/alzheimers-gnn-data/results
# GPU: Tesla T4

# %% [markdown]
# Install torch geometric. Do it quietly so as not to clutter up notebook

# %%
# !pip install torch-geometric --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.1 MB/s eta 0:00:00

# %% [markdown]
# Test MultiBandGCN is configured correctly

# %%
from torch_geometric.data import Data, Batch
from agnn.gnn.model import MultiBandGCN

# Create dummy delta and alpha2 graphs
delta = Data(x=torch.rand(125, 2), edge_index=torch.randint(0, 125, (2, 3100)), edge_attr=torch.rand(3100, 1), y=torch.tensor([1]))
alpha2 = Data(x=torch.rand(125, 2), edge_index=torch.randint(0, 125, (2, 3100)), edge_attr=torch.rand(3100, 1), y=torch.tensor([1]))

# Batch them. Simulate batch size 2.
delta_batch = Batch.from_data_list([delta, delta])
alpha2_batch = Batch.from_data_list([alpha2, alpha2])

# Instantiate and forward
model = MultiBandGCN()
logits = model(delta_batch, alpha2_batch)

print(f"Output shape: {logits.shape}")  # Should be (2, 2) if it worked properly
print(f"Sample logits: {logits}")
# Out:
# Output shape: torch.Size([2, 2])
# Sample logits: tensor([[ 0.0860,  0.0359],
#         [ 0.1537, -0.0273]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# Test load_subject_graphs() and pair_by_epochs() functions are working properly using the first five skeleton subjects

# %%
from agnn.paths import get_graphs_root
from agnn.gnn.data import load_subject_graphs, pair_by_epoch, make_cv_splits

# Load the first 5 subjects
subjects = ["sub-01", "sub-02", "sub-03", "sub-04", "sub-05"]
graphs = load_subject_graphs(subjects, get_graphs_root())
print(f"Total graphs: {len(graphs)}")

# Pair them
pairs = pair_by_epoch(graphs)
print(f"Total pairs: {len(pairs)}")
print(f"Labels: {set(p[2] for p in pairs)}")
# Out:
# Total graphs: 888
# Total pairs: 444
# Labels: {0}

# %% [markdown]
# Total graphs being 888 and total pairs being 444 looks correct.

# %% [markdown]
# Test that the collate_pairs function is working

# %%
from torch.utils.data import DataLoader
from agnn.gnn.data import GraphPairDataset, collate_pairs

# Wrap the pairs list in a PyTorch Dataset so DataLoader can iterate over it
dataset = GraphPairDataset(pairs)
loader = DataLoader(dataset, batch_size=4, shuffle=False, collate_fn=collate_pairs)

# Get the first batch to check catching and collation is working properly.
delta_batch, alpha2_batch, labels = next(iter(loader))
print(f"Delta batch: {delta_batch}")
print(f"Alpha2 batch: {alpha2_batch}")
print(f"Labels: {labels}")
print(f"Labels shape: {labels.shape}")
# Out:
# Delta batch: DataBatch(x=[500, 2], edge_index=[2, 12400], edge_attr=[12400, 1], subject_id=[4], epoch_idx=[4], band=[4], y=[4], batch=[500], ptr=[5])
# Alpha2 batch: DataBatch(x=[500, 2], edge_index=[2, 12400], edge_attr=[12400, 1], subject_id=[4], epoch_idx=[4], band=[4], y=[4], batch=[500], ptr=[5])
# Labels: tensor([0, 0, 0, 0])
# Labels shape: torch.Size([4])

# %% [markdown]
# Outputs are all looking as expected

# %% [markdown]
# Check that the model is consuming real batched data correctly.

# %%
from agnn.gnn.model import MultiBandGCN

# Set model to eval mode and run it on the batched data
model = MultiBandGCN()
model.eval()

# This is a diagnostic forwrad pass so no gradient tracking needed
with torch.no_grad():
    logits = model(delta_batch, alpha2_batch)

print(f"Logits shape: {logits.shape}") # Should see output shape (4, 2) because it matches 4 samples x 2 classes
print(f"Sample logits: {logits}")
# Out:
# Logits shape: torch.Size([4, 2])
# Sample logits: tensor([[-0.2202,  0.1060],
#         [-0.2216,  0.1049],
#         [-0.2195,  0.1066],
#         [-0.2219,  0.1046]])

# %% [markdown]
# Test that the training code is working correctly

# %%
import torch
from agnn.paths import get_graphs_root
from agnn.gnn.model import MultiBandGCN
from agnn.gnn.data import load_subject_graphs, pair_by_epoch, make_cv_splits, make_dataloader, verify_no_subject_leakage
from agnn.gnn.train import train_fold, set_seed

# Set seed and switch to cuda if its available
set_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Take a balanced sample. This one contains 15 subjects, 6 non carriers and 9 carriers
non_carriers = ["sub-01", "sub-02", "sub-03", "sub-04", "sub-05", "sub-06"]
carriers = ["sub-32", "sub-33", "sub-34", "sub-35", "sub-36", "sub-37", "sub-38", "sub-39", "sub-40"]
subjects = non_carriers + carriers

# Load graph .pt files for the sample and pair delta with alpha-2 by (subject, epoch)
graphs = load_subject_graphs(subjects, get_graphs_root())
pairs = pair_by_epoch(graphs)
n_pos = sum(p[2] for p in pairs)
print(f"Total pairs: {len(pairs)}, positive class: {n_pos}/{len(pairs)} = {n_pos/len(pairs):.2%}")

# Create CV splits. Chose fold 0 as a smoke test
splits = make_cv_splits(pairs, n_folds=3, seed=42)  # 3 folds so should be 5 subjects per fold
train_idx, val_idx = splits[0]

# Use the defensive function to check that no subject appears in train and val
verify_no_subject_leakage(pairs, train_idx, val_idx)

# Check fold has both classes
train_labels = [pairs[i][2] for i in train_idx]
val_labels = [pairs[i][2] for i in val_idx]
print(f"Train: {sum(train_labels)}/{len(train_labels)} positive")
print(f"Val: {sum(val_labels)}/{len(val_labels)} positive")

# Build the train and val loaders for the chosen fold
train_loader = make_dataloader(pairs, train_idx, batch_size=32, shuffle=True)
val_loader = make_dataloader(pairs, val_idx, batch_size=32, shuffle=False)

# Fresh model on the target device
model = MultiBandGCN().to(device)

# Set up a short training config for the purposes of running a smoke test
config = {"learning_rate": 0.001, "weight_decay": 0.0001, "epochs": 10, "patience": 20, "class_weights": [1.5, 1.0]}

# Train one fold end to end and report best validation AUC
result = train_fold(model, train_loader, val_loader, config, device, verbose=True)
print(f"\nBest AUC: {result['best_auc']:.4f} at epoch {result['best_epoch']}")
# Out:
# Total pairs: 1291, positive class: 757/1291 = 58.64%
# Train: 489/844 positive
# Val: 268/447 positive
# Epoch   1/10: train_loss=0.6909, val_loss=0.7067, val_auc=0.5513
# Epoch   2/10: train_loss=0.6831, val_loss=0.7049, val_auc=0.5513
# Epoch   3/10: train_loss=0.6680, val_loss=0.7045, val_auc=0.5519
# Epoch   4/10: train_loss=0.6458, val_loss=0.7146, val_auc=0.5520
# Epoch   5/10: train_loss=0.6273, val_loss=0.7287, val_auc=0.5517
# Epoch   6/10: train_loss=0.6223, val_loss=0.7464, val_auc=0.5522
# Epoch   7/10: train_loss=0.6243, val_loss=0.7496, val_auc=0.5522
# Epoch   8/10: train_loss=0.6252, val_loss=0.7598, val_auc=0.5525
# Epoch   9/10: train_loss=0.6268, val_loss=0.7450, val_auc=0.5514
# Epoch  10/10: train_loss=0.6232, val_loss=0.7560, val_auc=0.5524
#
# Best AUC: 0.5525 at epoch 8

# %% [markdown]
# ## Train the Model

# %%
import json
from datetime import datetime
from pathlib import Path
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve, precision_score, recall_score, f1_score, confusion_matrix
from agnn.paths import get_graphs_root, get_results_root
from agnn.gnn.model import MultiBandGCN
from agnn.gnn.data import load_subject_graphs, pair_by_epoch, make_cv_splits, make_dataloader, verify_no_subject_leakage
from agnn.gnn.train import train_fold, set_seed

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
if device.type == "cpu":
    print("WARNING: running on CPU. Training will be slow.")
# Out:
# Device: cuda

# %% [markdown]
# Set up configuration, ie define hyperparameters

# %%
config = {
    # Model hyperparameters
    "hidden_channels": 128,
    "embedding_dim": 32,
    "mlp_hidden": 32,
    "dropout": 0.5,

    # Training hyperparameters
    "learning_rate": 0.0001,
    "weight_decay": 0.0001,
    "batch_size": 32,
    "epochs": 200,
    "patience": 20,
    "class_weights": [1.5, 1.0],  # non-carrier (minority) to carrier (majority)

    # Cross-validation
    "n_folds": 5,
    "seed": 42,
}

# Print the config to check everything is looking right
print("Config:")
for k, v in config.items():
    print(f"  {k}: {v}")
# Out:
# Config:
#   hidden_channels: 128
#   embedding_dim: 32
#   mlp_hidden: 32
#   dropout: 0.5
#   learning_rate: 0.0001
#   weight_decay: 0.0001
#   batch_size: 32
#   epochs: 200
#   patience: 20
#   class_weights: [1.5, 1.0]
#   n_folds: 5
#   seed: 42

# %% [markdown]
# Load and pair all of the subjects

# %%
# Find all subject folders in the graphs directory
graphs_root = get_graphs_root()
subjects = sorted([d.name for d in graphs_root.iterdir() if d.is_dir()])
print(f"Found {len(subjects)} subjects at {graphs_root}")

# Load and pair all the graphs
graphs = load_subject_graphs(subjects, graphs_root)
pairs = pair_by_epoch(graphs)

# Check the cohort summary
n_positive = sum(p[2] for p in pairs)
print(f"Total pairs: {len(pairs)}")
print(f"Positive class (carriers): {n_positive} ({n_positive/len(pairs):.1%})")
print(f"Negative class (non-carriers): {len(pairs)-n_positive} ({(len(pairs)-n_positive)/len(pairs):.1%})")
# Out:
# Found 77 subjects at /content/graphs
# Total pairs: 6653
# Positive class (carriers): 3956 (59.5%)
# Negative class (non-carriers): 2697 (40.5%)

# %% [markdown]
# Create CV splits and results directory

# %%
# Create CV splits (seed is needed to control split)
set_seed(config["seed"])
splits = make_cv_splits(pairs, n_folds=config["n_folds"], seed=config["seed"])
print(f"Created {len(splits)} folds")

# This code creates timestamped results directory in Drive. Useful to see whats happening when
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
run_dir = get_results_root()/f"run_{timestamp}"
run_dir.mkdir(parents=True, exist_ok=True)
print(f"Results will save to: {run_dir}")

# Save config used for this run
with open(run_dir/"config.json", "w") as f:
    json.dump(config, f, indent=2)
# Out:
# Created 5 folds
# Results will save to: /content/drive/MyDrive/alzheimers-gnn-data/results/run_20260804_124346

# %% [markdown]
# Run 5-fold CV

# %%
# Create empty list to store fold results
fold_results = []

# This is the main CV loop. Each iteration trains and evaluates one fold end to end
for fold_idx, (train_idx, val_idx) in enumerate(splits):
    print(f"\n{'='*60}")
    print(f"Fold {fold_idx+1}/{config['n_folds']}")
    print(f"{'='*60}")

    # Use the defensive leakage check function created earlier to check for subject leakage
    verify_no_subject_leakage(pairs, train_idx, val_idx)

    # Report fold composition
    train_labels = [pairs[i][2] for i in train_idx]
    val_labels = [pairs[i][2] for i in val_idx]
    train_subjects = {pairs[i][0].subject_id for i in train_idx}
    val_subjects = {pairs[i][0].subject_id for i in val_idx}

    # For both train and validation datasets, record the number of pairs, subjects, and percentage of carriers
    print(f"Train: {len(train_idx)} pairs, {len(train_subjects)} subjects, {sum(train_labels)}/{len(train_labels)} positive ({sum(train_labels)/len(train_labels):.1%})")
    print(f"Val: {len(val_idx)} pairs, {len(val_subjects)} subjects, {sum(val_labels)}/{len(val_labels)} positive ({sum(val_labels)/len(val_labels):.1%})")

    # Fresh model per fold to ensure independent training
    set_seed(config["seed"]+fold_idx)  # different seed per fold, but reproducible

    # These values come from the config
    model = MultiBandGCN(hidden_channels=config["hidden_channels"], embedding_dim=config["embedding_dim"], mlp_hidden=config["mlp_hidden"],
                         dropout=config["dropout"]).to(device)

    # Create train and validation loaders
    train_loader = make_dataloader(pairs, train_idx, batch_size=config["batch_size"], shuffle=True)
    val_loader = make_dataloader(pairs, val_idx, batch_size=config["batch_size"], shuffle=False)

    # Create fold directory for outputs
    fold_dir = run_dir/f"fold_{fold_idx}"
    fold_dir.mkdir(exist_ok=True)

    # Train this fold
    result = train_fold(model=model, train_loader=train_loader, val_loader=val_loader, config=config, device=device, checkpoint_path=fold_dir/"best_model.pt",
        verbose=True)

    # Save the training history. This will be used to plot curves later on
    with open(fold_dir/"history.json", "w") as f:
        json.dump(result["history"], f, indent=2)

    # Save predictions at best epoch. This will be used later for downstream metrics
    np.savez(
        fold_dir/"predictions.npz",
        y_true=result["best_metrics"]["y_true"],
        y_prob=result["best_metrics"]["y_prob"],
    )

    # Save fold-level metrics summary
    y_true = result["best_metrics"]["y_true"]
    y_prob = result["best_metrics"]["y_prob"]
    y_pred = (y_prob > 0.5).astype(int)

    # Collect the metrics and metadata into a dictionary for this particular fold
    fold_summary = {
        "fold": fold_idx,
        "best_auc": result["best_auc"],
        "best_epoch": result["best_epoch"],
        "precision": precision_score(y_true, y_pred, zero_division=0),
        "recall": recall_score(y_true, y_pred, zero_division=0),
        "f1": f1_score(y_true, y_pred, zero_division=0),
        "n_train": len(train_idx),
        "n_val": len(val_idx),
        "n_train_subjects": len(train_subjects),
        "n_val_subjects": len(val_subjects),
    }

    # Save the fold summary to disk. This allows for later analysis,
    with open(fold_dir/"metrics.json", "w") as f:
        json.dump(fold_summary, f, indent=2)

    # Append to the running list created at the beginning. This can be used later for cross-fold aggregation.
    fold_results.append(fold_summary)

    print(f"\nFold {fold_idx+1} complete: AUC = {result['best_auc']:.4f} at epoch {result['best_epoch']}")
# Out:
# ============================================================
# Fold 1/5
# ============================================================
# Train: 5375 pairs, 62 subjects, 3025/5375 positive (56.3%)
# Val: 1278 pairs, 15 subjects, 931/1278 positive (72.8%)
# Epoch   1/200: train_loss=0.6933, val_loss=0.7032, val_auc=0.5417
# Epoch   2/200: train_loss=0.6915, val_loss=0.7114, val_auc=0.5204
# Epoch   3/200: train_loss=0.6903, val_loss=0.7171, val_auc=0.5203
# Epoch   4/200: train_loss=0.6901, val_loss=0.7180, val_auc=0.5204
# Epoch   5/200: train_loss=0.6889, val_loss=0.7204, val_auc=0.5204
# Epoch   6/200: train_loss=0.6886, val_loss=0.7225, val_auc=0.5205
# Epoch   7/200: train_loss=0.6883, val_loss=0.7230, val_auc=0.5205
# Epoch   8/200: train_loss=0.6876, val_loss=0.7186, val_auc=0.5206
# Epoch   9/200: train_loss=0.6858, val_loss=0.7229, val_auc=0.5206
# Epoch  10/200: train_loss=0.6847, val_loss=0.7279, val_auc=0.5206
# Epoch  11/200: train_loss=0.6852, val_loss=0.7266, val_auc=0.5206
# Epoch  12/200: train_loss=0.6853, val_loss=0.7338, val_auc=0.5205
# Epoch  13/200: train_loss=0.6853, val_loss=0.7240, val_auc=0.5206
# Epoch  14/200: train_loss=0.6841, val_loss=0.7324, val_auc=0.5206
# Epoch  15/200: train_loss=0.6839, val_loss=0.7283, val_auc=0.5206
# Epoch  16/200: train_loss=0.6837, val_loss=0.7335, val_auc=0.5206
# Epoch  17/200: train_loss=0.6843, val_loss=0.7313, val_auc=0.5206
# Epoch  18/200: train_loss=0.6831, val_loss=0.7370, val_auc=0.5206
# Epoch  19/200: train_loss=0.6846, val_loss=0.7365, val_auc=0.5205
# Epoch  20/200: train_loss=0.6834, val_loss=0.7312, val_auc=0.5205
# Epoch  21/200: train_loss=0.6840, val_loss=0.7414, val_auc=0.5205
# Early stopping at epoch 21: no improvement for 20 epochs (best AUC=0.5417 at epoch 1).
#
# Fold 1 complete: AUC = 0.5417 at epoch 1
#
# ============================================================
# Fold 2/5
# ============================================================
# Train: 5256 pairs, 61 subjects, 3086/5256 positive (58.7%)
# Val: 1397 pairs, 16 subjects, 870/1397 positive (62.3%)
# Epoch   1/200: train_loss=0.6972, val_loss=0.7207, val_auc=0.4710
# Epoch   2/200: train_loss=0.6944, val_loss=0.7134, val_auc=0.4705
# Epoch   3/200: train_loss=0.6920, val_loss=0.7066, val_auc=0.4706
# Epoch   4/200: train_loss=0.6909, val_loss=0.7031, val_auc=0.4704
# Epoch   5/200: train_loss=0.6895, val_loss=0.7008, val_auc=0.4703
# Epoch   6/200: train_loss=0.6892, val_loss=0.7021, val_auc=0.4698
# Epoch   7/200: train_loss=0.6881, val_loss=0.7045, val_auc=0.4696
# Epoch   8/200: train_loss=0.6868, val_loss=0.7075, val_auc=0.4695
# Epoch   9/200: train_loss=0.6860, val_loss=0.7042, val_auc=0.4696
# Epoch  10/200: train_loss=0.6865, val_loss=0.7047, val_auc=0.4696
# Epoch  11/200: train_loss=0.6852, val_loss=0.7098, val_auc=0.4693
# Epoch  12/200: train_loss=0.6837, val_loss=0.7074, val_auc=0.4694
# Epoch  13/200: train_loss=0.6838, val_loss=0.7142, val_auc=0.4693
# Epoch  14/200: train_loss=0.6835, val_loss=0.7121, val_auc=0.4693
# Epoch  15/200: train_loss=0.6842, val_loss=0.7150, val_auc=0.4693
# Epoch  16/200: train_loss=0.6834, val_loss=0.7149, val_auc=0.4693
# Epoch  17/200: train_loss=0.6826, val_loss=0.7147, val_auc=0.4693
# Epoch  18/200: train_loss=0.6831, val_loss=0.7180, val_auc=0.4692
# Epoch  19/200: train_loss=0.6842, val_loss=0.7161, val_auc=0.4692
# Epoch  20/200: train_loss=0.6835, val_loss=0.7147, val_auc=0.4693
# Epoch  21/200: train_loss=0.6837, val_loss=0.7220, val_auc=0.4692
# Early stopping at epoch 21: no improvement for 20 epochs (best AUC=0.4710 at epoch 1).
#
# Fold 2 complete: AUC = 0.4710 at epoch 1
#
# ============================================================
# Fold 3/5
# ============================================================
# Train: 5337 pairs, 62 subjects, 3164/5337 positive (59.3%)
# Val: 1316 pairs, 15 subjects, 792/1316 positive (60.2%)
# Epoch   1/200: train_loss=0.6930, val_loss=0.6975, val_auc=0.5014
# Epoch   2/200: train_loss=0.6920, val_loss=0.6966, val_auc=0.5015
# Epoch   3/200: train_loss=0.6914, val_loss=0.6963, val_auc=0.5014
# Epoch   4/200: train_loss=0.6906, val_loss=0.6955, val_auc=0.5013
# Epoch   5/200: train_loss=0.6900, val_loss=0.6952, val_auc=0.5013
# Epoch   6/200: train_loss=0.6884, val_loss=0.6945, val_auc=0.5013
# Epoch   7/200: train_loss=0.6885, val_loss=0.6944, val_auc=0.5013
# Epoch   8/200: train_loss=0.6871, val_loss=0.6921, val_auc=0.5013
# Epoch   9/200: train_loss=0.6874, val_loss=0.6924, val_auc=0.5014
# Epoch  10/200: train_loss=0.6871, val_loss=0.6927, val_auc=0.5014
# Epoch  11/200: train_loss=0.6863, val_loss=0.6922, val_auc=0.5014
# Epoch  12/200: train_loss=0.6864, val_loss=0.6948, val_auc=0.5013
# Epoch  13/200: train_loss=0.6859, val_loss=0.6957, val_auc=0.5013
# Epoch  14/200: train_loss=0.6852, val_loss=0.6945, val_auc=0.5013
# Epoch  15/200: train_loss=0.6851, val_loss=0.6940, val_auc=0.5013
# Epoch  16/200: train_loss=0.6863, val_loss=0.6911, val_auc=0.5013
# Epoch  17/200: train_loss=0.6855, val_loss=0.6917, val_auc=0.5013
# Epoch  18/200: train_loss=0.6861, val_loss=0.6908, val_auc=0.5013
# Epoch  19/200: train_loss=0.6863, val_loss=0.6928, val_auc=0.5013
# Epoch  20/200: train_loss=0.6845, val_loss=0.6938, val_auc=0.5013
# Epoch  21/200: train_loss=0.6840, val_loss=0.6932, val_auc=0.5013
# Epoch  22/200: train_loss=0.6854, val_loss=0.6926, val_auc=0.5013
# Early stopping at epoch 22: no improvement for 20 epochs (best AUC=0.5015 at epoch 2).
#
# Fold 3 complete: AUC = 0.5015 at epoch 2
#
# ============================================================
# Fold 4/5
# ============================================================
# Train: 5332 pairs, 62 subjects, 3242/5332 positive (60.8%)
# Val: 1321 pairs, 15 subjects, 714/1321 positive (54.0%)
# Epoch   1/200: train_loss=0.6936, val_loss=0.6930, val_auc=0.6661
# Epoch   2/200: train_loss=0.6933, val_loss=0.6924, val_auc=0.6838
# Epoch   3/200: train_loss=0.6931, val_loss=0.6917, val_auc=0.6826
# Epoch   4/200: train_loss=0.6930, val_loss=0.6913, val_auc=0.6824
# Epoch   5/200: train_loss=0.6926, val_loss=0.6909, val_auc=0.6823
# Epoch   6/200: train_loss=0.6927, val_loss=0.6903, val_auc=0.6822
# Epoch   7/200: train_loss=0.6927, val_loss=0.6900, val_auc=0.6822
# Epoch   8/200: train_loss=0.6926, val_loss=0.6895, val_auc=0.6822
# Epoch   9/200: train_loss=0.6924, val_loss=0.6893, val_auc=0.6823
# Epoch  10/200: train_loss=0.6926, val_loss=0.6887, val_auc=0.6822
# Epoch  11/200: train_loss=0.6926, val_loss=0.6887, val_auc=0.6823
# Epoch  12/200: train_loss=0.6923, val_loss=0.6881, val_auc=0.6823
# Epoch  13/200: train_loss=0.6928, val_loss=0.6881, val_auc=0.6823
# Epoch  14/200: train_loss=0.6923, val_loss=0.6878, val_auc=0.6823
# Epoch  15/200: train_loss=0.6923, val_loss=0.6874, val_auc=0.6823
# Epoch  16/200: train_loss=0.6926, val_loss=0.6872, val_auc=0.6823
# Epoch  17/200: train_loss=0.6924, val_loss=0.6871, val_auc=0.6823
# Epoch  18/200: train_loss=0.6924, val_loss=0.6866, val_auc=0.6823
# Epoch  19/200: train_loss=0.6924, val_loss=0.6864, val_auc=0.6823
# Epoch  20/200: train_loss=0.6927, val_loss=0.6865, val_auc=0.6823
# Epoch  21/200: train_loss=0.6919, val_loss=0.6858, val_auc=0.6823
# Epoch  22/200: train_loss=0.6923, val_loss=0.6856, val_auc=0.6823
# Early stopping at epoch 22: no improvement for 20 epochs (best AUC=0.6838 at epoch 2).
#
# Fold 4 complete: AUC = 0.6838 at epoch 2
#
# ============================================================
# Fold 5/5
# ============================================================
# Train: 5312 pairs, 61 subjects, 3307/5312 positive (62.3%)
# Val: 1341 pairs, 16 subjects, 649/1341 positive (48.4%)
# Epoch   1/200: train_loss=0.6930, val_loss=0.6936, val_auc=0.3865
# Epoch   2/200: train_loss=0.6927, val_loss=0.6941, val_auc=0.6019
# Epoch   3/200: train_loss=0.6915, val_loss=0.6946, val_auc=0.6056
# Epoch   4/200: train_loss=0.6923, val_loss=0.6942, val_auc=0.6061
# Epoch   5/200: train_loss=0.6919, val_loss=0.6938, val_auc=0.6065
# Epoch   6/200: train_loss=0.6918, val_loss=0.6938, val_auc=0.6065
# Epoch   7/200: train_loss=0.6917, val_loss=0.6936, val_auc=0.6066
# Epoch   8/200: train_loss=0.6914, val_loss=0.6932, val_auc=0.6068
# Epoch   9/200: train_loss=0.6913, val_loss=0.6929, val_auc=0.6069
# Epoch  10/200: train_loss=0.6909, val_loss=0.6924, val_auc=0.6070
# Epoch  11/200: train_loss=0.6905, val_loss=0.6923, val_auc=0.6069
# Epoch  12/200: train_loss=0.6906, val_loss=0.6921, val_auc=0.6069
# Epoch  13/200: train_loss=0.6905, val_loss=0.6918, val_auc=0.6069
# Epoch  14/200: train_loss=0.6908, val_loss=0.6911, val_auc=0.6070
# Epoch  15/200: train_loss=0.6899, val_loss=0.6913, val_auc=0.6069
# Epoch  16/200: train_loss=0.6899, val_loss=0.6904, val_auc=0.6070
# Epoch  17/200: train_loss=0.6906, val_loss=0.6899, val_auc=0.6071
# Epoch  18/200: train_loss=0.6904, val_loss=0.6894, val_auc=0.6072
# Epoch  19/200: train_loss=0.6898, val_loss=0.6891, val_auc=0.6072
# Epoch  20/200: train_loss=0.6906, val_loss=0.6890, val_auc=0.6071
# Epoch  21/200: train_loss=0.6905, val_loss=0.6885, val_auc=0.6071
# Epoch  22/200: train_loss=0.6898, val_loss=0.6888, val_auc=0.6071
# Epoch  23/200: train_loss=0.6903, val_loss=0.6884, val_auc=0.6071
# Epoch  24/200: train_loss=0.6904, val_loss=0.6882, val_auc=0.6072
# Epoch  25/200: train_loss=0.6901, val_loss=0.6881, val_auc=0.6071
# Epoch  26/200: train_loss=0.6898, val_loss=0.6880, val_auc=0.6071
# Epoch  27/200: train_loss=0.6903, val_loss=0.6878, val_auc=0.6071
# Epoch  28/200: train_loss=0.6902, val_loss=0.6879, val_auc=0.6070
# Epoch  29/200: train_loss=0.6900, val_loss=0.6870, val_auc=0.6072
# Epoch  30/200: train_loss=0.6899, val_loss=0.6870, val_auc=0.6072
# Epoch  31/200: train_loss=0.6899, val_loss=0.6869, val_auc=0.6071
# Epoch  32/200: train_loss=0.6897, val_loss=0.6875, val_auc=0.6070
# Epoch  33/200: train_loss=0.6895, val_loss=0.6871, val_auc=0.6071
# Epoch  34/200: train_loss=0.6891, val_loss=0.6872, val_auc=0.6070
# Epoch  35/200: train_loss=0.6900, val_loss=0.6863, val_auc=0.6078
# Epoch  36/200: train_loss=0.6899, val_loss=0.6860, val_auc=0.6092
# Epoch  37/200: train_loss=0.6897, val_loss=0.6865, val_auc=0.6078
# Epoch  38/200: train_loss=0.6902, val_loss=0.6866, val_auc=0.6078
# Epoch  39/200: train_loss=0.6897, val_loss=0.6863, val_auc=0.6083
# Epoch  40/200: train_loss=0.6893, val_loss=0.6861, val_auc=0.6088
# Epoch  41/200: train_loss=0.6894, val_loss=0.6861, val_auc=0.6077
# Epoch  42/200: train_loss=0.6903, val_loss=0.6856, val_auc=0.6084
# Epoch  43/200: train_loss=0.6899, val_loss=0.6856, val_auc=0.6077
# Epoch  44/200: train_loss=0.6907, val_loss=0.6860, val_auc=0.6080
# Epoch  45/200: train_loss=0.6903, val_loss=0.6860, val_auc=0.6080
# Epoch  46/200: train_loss=0.6904, val_loss=0.6867, val_auc=0.6075
# Epoch  47/200: train_loss=0.6897, val_loss=0.6859, val_auc=0.6084
# Epoch  48/200: train_loss=0.6898, val_loss=0.6862, val_auc=0.6083
# Epoch  49/200: train_loss=0.6897, val_loss=0.6863, val_auc=0.6078
# Epoch  50/200: train_loss=0.6907, val_loss=0.6861, val_auc=0.6079
# Epoch  51/200: train_loss=0.6898, val_loss=0.6867, val_auc=0.6075
# Epoch  52/200: train_loss=0.6893, val_loss=0.6862, val_auc=0.6081
# Epoch  53/200: train_loss=0.6897, val_loss=0.6858, val_auc=0.6087
# Epoch  54/200: train_loss=0.6897, val_loss=0.6855, val_auc=0.6093
# Epoch  55/200: train_loss=0.6901, val_loss=0.6857, val_auc=0.6088
# Epoch  56/200: train_loss=0.6894, val_loss=0.6861, val_auc=0.6082
# Epoch  57/200: train_loss=0.6898, val_loss=0.6860, val_auc=0.6080
# Epoch  58/200: train_loss=0.6897, val_loss=0.6860, val_auc=0.6084
# Epoch  59/200: train_loss=0.6896, val_loss=0.6857, val_auc=0.6088
# Epoch  60/200: train_loss=0.6902, val_loss=0.6856, val_auc=0.6085
# Epoch  61/200: train_loss=0.6904, val_loss=0.6854, val_auc=0.6087
# Epoch  62/200: train_loss=0.6891, val_loss=0.6857, val_auc=0.6076
# Epoch  63/200: train_loss=0.6909, val_loss=0.6851, val_auc=0.6091
# Epoch  64/200: train_loss=0.6895, val_loss=0.6852, val_auc=0.6094
# Epoch  65/200: train_loss=0.6896, val_loss=0.6854, val_auc=0.6086
# Epoch  66/200: train_loss=0.6909, val_loss=0.6852, val_auc=0.6090
# Epoch  67/200: train_loss=0.6891, val_loss=0.6858, val_auc=0.6083
# Epoch  68/200: train_loss=0.6897, val_loss=0.6851, val_auc=0.6093
# Epoch  69/200: train_loss=0.6891, val_loss=0.6857, val_auc=0.6085
# Epoch  70/200: train_loss=0.6897, val_loss=0.6857, val_auc=0.6083
# Epoch  71/200: train_loss=0.6889, val_loss=0.6854, val_auc=0.6090
# Epoch  72/200: train_loss=0.6899, val_loss=0.6855, val_auc=0.6083
# Epoch  73/200: train_loss=0.6894, val_loss=0.6851, val_auc=0.6091
# Epoch  74/200: train_loss=0.6897, val_loss=0.6852, val_auc=0.6085
# Epoch  75/200: train_loss=0.6898, val_loss=0.6854, val_auc=0.6081
# Epoch  76/200: train_loss=0.6902, val_loss=0.6856, val_auc=0.6081
# Epoch  77/200: train_loss=0.6891, val_loss=0.6858, val_auc=0.6078
# Epoch  78/200: train_loss=0.6898, val_loss=0.6846, val_auc=0.6101
# Epoch  79/200: train_loss=0.6890, val_loss=0.6852, val_auc=0.6085
# Epoch  80/200: train_loss=0.6896, val_loss=0.6854, val_auc=0.6084
# Epoch  81/200: train_loss=0.6895, val_loss=0.6852, val_auc=0.6090
# Epoch  82/200: train_loss=0.6896, val_loss=0.6852, val_auc=0.6084
# Epoch  83/200: train_loss=0.6900, val_loss=0.6852, val_auc=0.6089
# Epoch  84/200: train_loss=0.6898, val_loss=0.6855, val_auc=0.6080
# Epoch  85/200: train_loss=0.6902, val_loss=0.6852, val_auc=0.6088
# Epoch  86/200: train_loss=0.6899, val_loss=0.6851, val_auc=0.6096
# Epoch  87/200: train_loss=0.6893, val_loss=0.6857, val_auc=0.6084
# Epoch  88/200: train_loss=0.6891, val_loss=0.6855, val_auc=0.6084
# Epoch  89/200: train_loss=0.6894, val_loss=0.6856, val_auc=0.6085
# Epoch  90/200: train_loss=0.6900, val_loss=0.6853, val_auc=0.6091
# Epoch  91/200: train_loss=0.6886, val_loss=0.6855, val_auc=0.6085
# Epoch  92/200: train_loss=0.6893, val_loss=0.6843, val_auc=0.6108
# Epoch  93/200: train_loss=0.6892, val_loss=0.6849, val_auc=0.6084
# Epoch  94/200: train_loss=0.6897, val_loss=0.6847, val_auc=0.6094
# Epoch  95/200: train_loss=0.6893, val_loss=0.6845, val_auc=0.6102
# Epoch  96/200: train_loss=0.6901, val_loss=0.6851, val_auc=0.6084
# Epoch  97/200: train_loss=0.6893, val_loss=0.6849, val_auc=0.6092
# Epoch  98/200: train_loss=0.6893, val_loss=0.6850, val_auc=0.6085
# Epoch  99/200: train_loss=0.6897, val_loss=0.6845, val_auc=0.6095
# Epoch 100/200: train_loss=0.6895, val_loss=0.6845, val_auc=0.6098
# Epoch 101/200: train_loss=0.6897, val_loss=0.6847, val_auc=0.6091
# Epoch 102/200: train_loss=0.6895, val_loss=0.6846, val_auc=0.6099
# Epoch 103/200: train_loss=0.6896, val_loss=0.6842, val_auc=0.6105
# Epoch 104/200: train_loss=0.6897, val_loss=0.6843, val_auc=0.6101
# Epoch 105/200: train_loss=0.6890, val_loss=0.6848, val_auc=0.6085
# Epoch 106/200: train_loss=0.6888, val_loss=0.6847, val_auc=0.6089
# Epoch 107/200: train_loss=0.6904, val_loss=0.6844, val_auc=0.6110
# Epoch 108/200: train_loss=0.6890, val_loss=0.6855, val_auc=0.6083
# Epoch 109/200: train_loss=0.6898, val_loss=0.6844, val_auc=0.6111
# Epoch 110/200: train_loss=0.6897, val_loss=0.6852, val_auc=0.6092
# Epoch 111/200: train_loss=0.6900, val_loss=0.6854, val_auc=0.6089
# Epoch 112/200: train_loss=0.6894, val_loss=0.6848, val_auc=0.6103
# Epoch 113/200: train_loss=0.6897, val_loss=0.6853, val_auc=0.6091
# Epoch 114/200: train_loss=0.6893, val_loss=0.6847, val_auc=0.6115
# Epoch 115/200: train_loss=0.6893, val_loss=0.6843, val_auc=0.6122
# Epoch 116/200: train_loss=0.6901, val_loss=0.6852, val_auc=0.6091
# Epoch 117/200: train_loss=0.6892, val_loss=0.6853, val_auc=0.6091
# Epoch 118/200: train_loss=0.6893, val_loss=0.6857, val_auc=0.6082
# Epoch 119/200: train_loss=0.6903, val_loss=0.6849, val_auc=0.6106
# Epoch 120/200: train_loss=0.6891, val_loss=0.6847, val_auc=0.6105
# Epoch 121/200: train_loss=0.6889, val_loss=0.6849, val_auc=0.6096
# Epoch 122/200: train_loss=0.6902, val_loss=0.6846, val_auc=0.6108
# Epoch 123/200: train_loss=0.6897, val_loss=0.6848, val_auc=0.6108
# Epoch 124/200: train_loss=0.6899, val_loss=0.6845, val_auc=0.6121
# Epoch 125/200: train_loss=0.6893, val_loss=0.6849, val_auc=0.6104
# Epoch 126/200: train_loss=0.6889, val_loss=0.6852, val_auc=0.6098
# Epoch 127/200: train_loss=0.6889, val_loss=0.6854, val_auc=0.6090
# Epoch 128/200: train_loss=0.6893, val_loss=0.6844, val_auc=0.6117
# Epoch 129/200: train_loss=0.6893, val_loss=0.6847, val_auc=0.6102
# Epoch 130/200: train_loss=0.6895, val_loss=0.6848, val_auc=0.6094
# Epoch 131/200: train_loss=0.6890, val_loss=0.6846, val_auc=0.6108
# Epoch 132/200: train_loss=0.6893, val_loss=0.6845, val_auc=0.6110
# Epoch 133/200: train_loss=0.6891, val_loss=0.6848, val_auc=0.6094
# Epoch 134/200: train_loss=0.6893, val_loss=0.6842, val_auc=0.6112
# Epoch 135/200: train_loss=0.6898, val_loss=0.6845, val_auc=0.6102
# Early stopping at epoch 135: no improvement for 20 epochs (best AUC=0.6122 at epoch 115).
#
# Fold 5 complete: AUC = 0.6122 at epoch 115

# %% [markdown]
# Aggregate cross fold metrics

# %%
# Build cross-fold summary df
summary_df = pd.DataFrame(fold_results)
summary_df.to_csv(run_dir/"cross_fold_metrics.csv", index=False)
print("Cross-fold metrics:")
print(summary_df.to_string(index=False))

# Create some overall statistics
mean_auc = summary_df["best_auc"].mean()
std_auc = summary_df["best_auc"].std()
mean_f1 = summary_df["f1"].mean()

# Create a printed summary
print(f"\n{'='*60}")
print(f"Cross-fold summary (n_folds={config['n_folds']})")
print(f"{'='*60}")
print(f"AUC: {mean_auc:.4f} +/- {std_auc:.4f}")
print(f"F1: {mean_f1:.4f} +/- {summary_df['f1'].std():.4f}")
print(f"Precision: {summary_df['precision'].mean():.4f} +/- {summary_df['precision'].std():.4f}")
print(f"Recall: {summary_df['recall'].mean():.4f} +/- {summary_df['recall'].std():.4f}")

# Save top-level summary
top_summary = {
    "config": config,
    "n_subjects": len(subjects),
    "n_pairs": len(pairs),
    "class_balance": {
        "positive": n_positive,
        "negative": len(pairs)-n_positive,
        "ratio_pos": n_positive/len(pairs),
    },
    "cross_fold_auc": {
        "mean": float(mean_auc),
        "std": float(std_auc),
        "per_fold": summary_df["best_auc"].tolist(),
    },
    "cross_fold_f1": {
        "mean": float(mean_f1),
        "std": float(summary_df["f1"].std()),
    },
}

# Write the top level summary to the disk in Drive so it can survive session end
with open(run_dir/"summary.json", "w") as f:
    json.dump(top_summary, f, indent=2)

print(f"\nAll results saved to: {run_dir}")
# Out:
# Cross-fold metrics:
#  fold  best_auc  best_epoch  precision   recall       f1  n_train  n_val  n_train_subjects  n_val_subjects
#     0  0.541742           1   0.000000 0.000000 0.000000     5375   1278                62              15
#     1  0.470974           1   0.000000 0.000000 0.000000     5256   1397                61              16
#     2  0.501482           2   1.000000 0.001263 0.002522     5337   1316                62              15
#     3  0.683806           2   0.540500 1.000000 0.701720     5332   1321                62              15
#     4  0.612160         115   0.521028 0.687211 0.592691     5312   1341                61              16
#
# ============================================================
# Cross-fold summary (n_folds=5)
# ============================================================
# AUC: 0.5620 +/- 0.0862
# F1: 0.2594 +/- 0.3561
# Precision: 0.4123 +/- 0.4224
# Recall: 0.3377 +/- 0.4749
#
# All results saved to: /content/drive/MyDrive/alzheimers-gnn-data/results/run_20260804_124346

# %% [markdown]
# Training curves plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Iterate over the folds. Log each fold's saved history and plot its curves.
for fold_idx in range(config["n_folds"]):
    fold_dir = run_dir/f"fold_{fold_idx}"
    with open(fold_dir/"history.json") as f:
        history = json.load(f)

    # Left axis will be train/validation loss curves. Right will be validation AUC
    epochs = range(1, len(history["train_loss"])+1)
    axes[0].plot(epochs, history["train_loss"], label=f"Fold {fold_idx+1} train", alpha=0.7)
    axes[0].plot(epochs, history["val_loss"], label=f"Fold {fold_idx+1} val", linestyle="--", alpha=0.7)
    axes[1].plot(epochs, history["val_auc"], label=f"Fold {fold_idx+1}", alpha=0.7)

# Title, labels, legend and grid for left hand graph
axes[0].set_title("Loss per epoch")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Cross-entropy loss")
axes[0].legend(fontsize=8, loc="upper right")
axes[0].grid(alpha=0.3)

# Title, labels, legend and grid for right hand graph
axes[1].set_title("Validation AUC per epoch")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("ROC-AUC")
axes[1].axhline(y=0.5, color="gray", linestyle=":", label="Chance")
axes[1].legend(fontsize=8, loc="lower right")
axes[1].grid(alpha=0.3)

# Display and save the graphs
plt.tight_layout()
plt.savefig(run_dir/"training_curves.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ROC curves plot

# %%
fig, ax = plt.subplots(figsize=(7, 7))

# Plot the ROC curve for each fold individually, this shows the variation between folds
for fold_idx in range(config["n_folds"]):
    fold_dir = run_dir/f"fold_{fold_idx}"
    preds = np.load(fold_dir/"predictions.npz")
    fpr, tpr, _ = roc_curve(preds["y_true"], preds["y_prob"])
    auc = roc_auc_score(preds["y_true"], preds["y_prob"])
    ax.plot(fpr, tpr, alpha=0.5, label=f"Fold {fold_idx + 1} (AUC={auc:.3f})")

# Prepare lists to collect predictions across folds for the pooled ROC
all_y_true = []
all_y_prob = []

# Load each fold's predictions and append to the running lsist
for fold_idx in range(config["n_folds"]):
    preds = np.load(run_dir/f"fold_{fold_idx}"/"predictions.npz")
    all_y_true.append(preds["y_true"])
    all_y_prob.append(preds["y_prob"])

# Flatten into single arrays covering the whole cohort
all_y_true = np.concatenate(all_y_true)
all_y_prob = np.concatenate(all_y_prob)

# Compute the pooled ROC and AUC across all folds combined
fpr, tpr, _ = roc_curve(all_y_true, all_y_prob)
pooled_auc = roc_auc_score(all_y_true, all_y_prob)

# Draw the pooled ROC on top of the per-fold curves. This should give a cohort-level view
ax.plot(fpr, tpr, color="black", linewidth=2, label=f"Pooled (AUC={pooled_auc:.3f})")

# Chance line
ax.plot([0, 1], [0, 1], "k:", alpha=0.5, label="Chance")

# Title, labelss, legend and grid
ax.set_xlabel("False Positive Rate")
ax.set_ylabel("True Positive Rate")
ax.set_title(f"ROC Curves (5-fold CV and N={len(subjects)})")
ax.legend(loc="lower right")
ax.grid(alpha=0.3)
ax.set_aspect("equal")

# Display and save the graph
plt.tight_layout()
plt.savefig(run_dir/"roc_curves.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## SUMMARY OF TUNED GNN
#
# This is the best GNN result that can be achieved using hyperparameter tuning. The first model had mean AUC 0.556 +/- 0.091, while this best model has mean AUC 0.562 +/- 0.086. This is an imporvement of +0.006 AUC, which is statistically indistinguishable from the first result. There is slightly better performance but essentially reproducing the same pattern:
#
# - Folds 1, 2 and 3: chance (0.47-0.54)
# - Fold 4: real signal (0.68)
# - Fold 5: some signal (0.61)
#
# So, the hyperparameters aren't the bottleneck. Can identify two possible reasons for the performance ceiling:
#
# (1) Per epoch representation is noisy.
#
# (2) The signal is genuinely weak. Not too unexpected for this problem.
#
# (2) isn't testable but (1) is. The next step is to try subject level aggregation and then retrain the GNN.
